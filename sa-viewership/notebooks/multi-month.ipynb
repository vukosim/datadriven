# %%
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.style.use('fivethirtyeight')
#Some default stuff for my plotting
aspect_mult = 0.9
figsize(aspect_mult*16,aspect_mult*9)
linewidth = 3

# %%
df_june = pd.read_csv('../data/tabula-To-20-TV-Shows-June-2016-cleaned.csv')
df_june["Programme"] = df_june["Programme"].map(lambda x: x.strip().replace(' ', '_').lower())
df_may = pd.read_csv('../data/tabula-Top-20-TV-Shows-May-2016-cleaned.csv')
df_may["Programme"] = df_may["ProgrammeTitle"].map(lambda x: x.strip().replace(' ', '_').lower())
df_april = pd.read_csv('../data/tabula-Top-20-TV-Shows-Apr-2016-cleaned.csv')
df_april["Programme"] = df_april["ProgrammeTitle"].map(lambda x: x.strip().replace(' ', '_').lower())
df_march = pd.read_csv('../data/tabula-Top-20-TV-Shows-Mar-2016-cleaned.csv')
df_march["Programme"] = df_march["ProgrammeTitle"].map(lambda x: x.strip().replace(' ', '_').lower())
df_february = pd.read_csv('../data/tabula-Top-20-TV-Shows-Feb-2016-cleaned.csv')
df_february["Programme"] = df_february["Programme"].map(lambda x: x.strip().replace(' ', '_').lower())

# %%
df_june.head()
# Out:
#     Day        Date  From    To Station                  Programme Genre  \
# 0   Tue  07/06/2016  2032  2103      S1                      uzalo  Dram
# 1   Wed  22/06/2016  2001  2030      S1     generations_the_legacy  Soap
# 2   Tue  21/06/2016  1831  1901      S1                 skeem_saam  Dram
# 3   Tue  21/06/2016  1827  1831      S1  vodacom_yebo_millionaires  Quiz
# 4  Thur  23/06/2016  2033  2102      S1             mfolozi_street  Dram
#
#      AR  Viewers  Share
# 0  24.6  8276462   66.3
# 1  23.8  8018765   66.2
# 2  22.1  7465141   62.0
# 3  17.3  5836157   53.1
# 4  16.8  5659818   51.0

# %%
df_may.head()
# Out:
#    Day        Date  From    To Station  \
# 0  Wed  18/05/2016  1930  1958     ETV
# 1  Sat  21/05/2016  1930  2117     ETV
# 2  Mon  23/05/2016  1900  1929     ETV
# 3  Sat  14/05/2016  1930  2114     ETV
# 4  Sun  22/05/2016  1800  1801     ETV
#
#                            ProgrammeTitle Genre    AR  Viewers  Share  \
# 0                                 Scandal  Soap  14.5  4877167   40.8
# 1    Alvin and the Chipmunks: Chipwrecked  Movi  11.2  3763629   39.8
# 2                             Rhythm City  Dram  10.4  3507373   29.8
# 3  Alvin and the Chipmunks the Squeakquel  Movi   9.6  3247740   35.8
# 4                 E News Direct Headlines  News   8.4  2822181   29.3
#
#                                 Programme
# 0                                 scandal
# 1    alvin_and_the_chipmunks:_chipwrecked
# 2                             rhythm_city
# 3  alvin_and_the_chipmunks_the_squeakquel
# 4                 e_news_direct_headlines

# %%
df_april.head()
# Out:
#     Day        Date  From      To Station                  ProgrammeTitle  \
# 0  Thur  21/04/2016  1931  2000.0     ETV                         Scandal
# 1  Thur  21/04/2016  1901  1929.0     ETV                     Rhythm City
# 2   Sun  03/04/2016  1959  2237.0     ETV           Live Free or Die Hard
# 3   Sun  24/04/2016  2000  2209.0     ETV  Rise of the Planet of the Apes
# 4   Sun  17/04/2016  2000  2200.0     ETV                          Faster
#
#   Genre    AR    Viewers  Share  Unnamed: 10                       Programme
# 0  Soap  14.5  4893383.0   40.4          NaN                         scandal
# 1  Dram  10.7  3614525.0   30.6          NaN                     rhythm_city
# 2  Movi   9.3  3144309.0   39.4          NaN           live_free_or_die_hard
# 3  Movi   8.8  2982434.0   36.8          NaN  rise_of_the_planet_of_the_apes
# 4  Movi   8.4  2847695.0   34.6          NaN                          faster

# %%
df_march.head()
# Out:
#    Day        Date  From      To Station  ProgrammeTitle Genre    AR  Viewers  \
# 0  Tue  22/03/2016  1931  2000.0     ETV         Scandal  Soap  13.6  4565369
# 1  Sun  13/03/2016  2000  2148.0     ETV    Rush Hour II  Movi  10.9  3656788
# 2  Wed  30/03/2016  1902  1928.0     ETV     Rhythm City  Dram  10.6  3578799
# 3  Sun  06/03/2016  2000  2159.0     ETV       Rush Hour  Movi   9.8  3305778
# 4  Tue  29/03/2016  1959  2029.0     ETV  Ashes to Ashes  Dram   8.4  2841009
#
#    Share       Programme
# 0   38.5         scandal
# 1   41.6    rush_hour_ii
# 2   31.7     rhythm_city
# 3   40.0       rush_hour
# 4   24.9  ashes_to_ashes

# %%
df_february.head()
# Out:
#    Day        Date  From      To Station              Programme Genre    AR  \
# 0  Wed  17/02/2016  1929  1958.0     ETV                scandal  Soap  12.1
# 1  Sun  28/02/2016  2000  2250.0     ETV  the_amazing_spiderman  Movi   8.0
# 2  Wed  24/02/2016  1900  1928.0     ETV            rhythm_city  Dram   7.8
# 3  Sun  07/02/2016  2000  2255.0     ETV          casino_royale  Movi   7.7
# 4  Sun  21/02/2016  1959  2222.0     ETV                    300  Movi   7.4
#
#    Viewers  Share
# 0  4082438   38.0
# 1  2689932   38.2
# 2  2634446   25.8
# 3  2582072   39.9
# 4  2491318   32.1

# %%
result_s1_june =  df_june.loc[df_june['Station'] == 'S1']
result_s1_may =  df_may.loc[df_may['Station'] == 'S1']
result_s1_april =  df_april.loc[df_april['Station'] == 'S1']
result_s1_march =  df_march.loc[df_march['Station'] == 'S1']
result_s1_february =  df_february.loc[df_february['Station'] == 'S1']

# %%
result_s1_june
# Out:
#      Day        Date  From    To Station  \
# 0    Tue  07/06/2016  2032  2103      S1
# 1    Wed  22/06/2016  2001  2030      S1
# 2    Tue  21/06/2016  1831  1901      S1
# 3    Tue  21/06/2016  1827  1831      S1
# 4   Thur  23/06/2016  2033  2102      S1
# 5    Fri  24/06/2016  2030  2100      S1
# 6    Wed  29/06/2016  1856  1900      S1
# 7    Sat  11/06/2016  1900  1931      S1
# 8    Mon  06/06/2016  1901  1931      S1
# 9    Tue  21/06/2016  1800  1827      S1
# 10   Wed  29/06/2016  1900  2058      S1
# 11   Wed  15/06/2016  1932  2001      S1
# 12   Tue  07/06/2016  1931  2002      S1
# 13   Sat  11/06/2016  1759  1900      S1
# 14  Thur  09/06/2016  1931  2000      S1
# 15   Wed  22/06/2016  1800  1830      S1
# 16   Fri  24/06/2016  1930  2000      S1
# 17   Mon  27/06/2016  1759  1829      S1
# 18   Fri  17/06/2016  1801  1830      S1
# 19   Fri  10/06/2016  2030  2058      S1
#
#                                    Programme Genre    AR  Viewers  Share
# ...

# %%
result_s1_may
# Out:
#      Day        Date  From    To Station            ProgrammeTitle Genre  \
# 40   Tue  24/05/2016  2001  2031      S1    Generations the Legacy  Soap
# 41   Tue  24/05/2016  2032  2102      S1                     Uzalo  Dram
# 42   Tue  24/05/2016  1830  1901      S1                Skeem Saam  Dram
# 43   Tue  17/05/2016  1829  1832      S1  Vodacom Yebo Millionaire  Quiz
# 44  Thur  19/05/2016  2031  2101      S1            Mfolozi Street  Dram
# 45   Tue  17/05/2016  1904  1934      S1                Xhosa News  News
# 46   Fri  27/05/2016  2033  2102      S1               Dream World  Dram
# 47   Tue  17/05/2016  1935  2004      S1              Selimathunzi  Vari
# 48   Wed  18/05/2016  1902  1932      S1                 Zulu News  News
# 49   Tue  17/05/2016  1800  1828      S1                 Nyan Nyan  Real
# 50   Fri  06/05/2016  2031  2059      S1                       Jab  Dram
# 51   Sat  21/05/2016  1801  1900      S1        Friends Like These  Vari
# ...

# %%
result_s1_april
# Out:
#      Day        Date  From      To Station                   ProgrammeTitle  \
# 60   Tue  19/04/2016  2002  2032.0      S1           Generations the Legacy
# 61   Tue  19/04/2016  2032  2102.0      S1                            Uzalo
# 62  Thur  21/04/2016  1831  1901.0      S1                       Skeem Saam
# 63   Tue  19/04/2016  1827  1831.0      S1        Vodacom Yebo Millionaires
# 64  Thur  21/04/2016  2034  2104.0      S1                   Mfolozi Street
# 65   Mon  25/04/2016  1933  2004.0      S1                       Ses Top La
# 66   Fri  15/04/2016  2031  2100.0      S1                              Jab
# 67   Mon  25/04/2016  1903  1933.0      S1                        Zulu News
# 68   Tue  05/04/2016  1901  1931.0      S1                       Xhosa News
# 69  Thur  28/04/2016  1932  2002.0      S1                           Zaziwa
# 70   Fri  01/04/2016  1936  2005.0      S1                         Live Amp
# ...

# %%
generations = [df_june.loc[df_june['Programme'] == 'generations_the_legacy'].Viewers.values[0],
               df_may.loc[df_may['Programme'] == 'generations_the_legacy'].Viewers.values[0],
               df_april.loc[df_april['Programme'] == 'generations_the_legacy'].Viewers.values[0],
               df_march.loc[df_march['Programme'] == 'generations_the_legacy'].Viewers.values[0],
               df_february.loc[df_february['Programme'] == 'generations_the_legacy'].Viewers.values[0]]
uzalo = [df_june.loc[df_june['Programme'] == 'uzalo'].Viewers.values[0],
               df_may.loc[df_may['Programme'] == 'uzalo'].Viewers.values[0],
               df_april.loc[df_april['Programme'] == 'uzalo'].Viewers.values[0],
               df_march.loc[df_march['Programme'] == 'uzalo'].Viewers.values[0],
               df_february.loc[df_february['Programme'] == 'uzalo'].Viewers.values[0]]
skeemsaam = [df_june.loc[df_june['Programme'] == 'skeem_saam'].Viewers.values[0],
               df_may.loc[df_may['Programme'] == 'skeem_saam'].Viewers.values[0],
               df_april.loc[df_april['Programme'] == 'skeem_saam'].Viewers.values[0],
               df_march.loc[df_march['Programme'] == 'skeem_saam'].Viewers.values[0],
               df_february.loc[df_february['Programme'] == 'skeem_saam'].Viewers.values[0]]
mfolozi_street= [df_june.loc[df_june['Programme'] == 'mfolozi_street'].Viewers.values[0],
               df_may.loc[df_may['Programme'] == 'mfolozi_street'].Viewers.values[0],
               df_april.loc[df_april['Programme'] == 'mfolozi_street'].Viewers.values[0],
               df_march.loc[df_march['Programme'] == 'mfolozi_street'].Viewers.values[0],
               df_february.loc[df_february['Programme'] == 'mfolozi_street'].Viewers.values[0]]
# ses_top_la= [df_june.loc[df_june['Programme'] == 'ses_top_la'].Viewers.values[0],
#                df_may.loc[df_may['Programme'] == 'ses_top_la'].Viewers.values[0],
#                df_april.loc[df_april['Programme'] == 'ses_top_la'].Viewers.values[0],
#                df_march.loc[df_march['Programme'] == 'ses_top_la'].Viewers.values[0],
#                df_february.loc[df_february['Programme'] == 'ses_top_la'].Viewers.values[0]]

# %%
df_plot = pd.DataFrame(np.array([mfolozi_street,skeemsaam,generations,uzalo]).T, 
                       columns = ['MfoloziStreet','SkeemSaam','GenerationsTheLegacy','Uzalo'])
df_plot.index = ['June','May','April','March','February']
df_plot = df_plot.reindex(index=df_plot.index[::-1])

# %%
fig, axes = pyplot.subplots(1, 1, sharey=True)
df_plot.plot(kind='bar',ax=axes)
axes.set_title("SABC 1 Viewership Comparison 2016", fontsize = 20, color='k')
plt.legend(loc="lower left", shadow=True)
axes.set_ylabel("Monthly Number of Viewers", fontsize = 18, color='k' )
axes.set_xlabel("Month", fontsize = 18, color='k' )
# pyplot.figtext(0.5, 0.85, 'By ?@vukosi http://www.vima.co.za \nSource: StatsSA' , fontsize=12,color='k')
plt.text(0.5, -0.205,'Data Source: TAMS || Author: Vukosi Marivate (http://www.vima.co.za / @vukosi)',
     horizontalalignment='right',
     verticalalignment='center',
     transform = axes.transAxes,color='black',fontsize=12)
pyplot.savefig('../plots/sabc1_top_shows_feb_june_2016.png',bbox_inches='tight',dpi=300)
